# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# ...
#   Using cached alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached albumentations-0.1.12.tar.gz (59 kB)
# ...
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#   Using cached arviz-0.12.1-py3-none-any.whl (1.6 MB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached astropy-4.3.1-cp38-cp38-win_amd64.whl (6.4 MB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached atari_py-0.2.9-cp38-cp38-win_amd64.whl (1.6 MB)
# ...
#   Using cached atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# ...
#   Using cached audioread-2.1.9.tar.gz (377 kB)
# ...
#   Using cached autogoal-0.4.4-py3-none-any.whl (134 kB)
# ...
#   Using cached autograd-1.4-py3-none-any.whl (48 kB)
# ...
#   Using cached Babel-2.10.1-py3-none-any.whl (9.5 MB)
# ...
#   Using cached base58-2.1.1-py3-none-any.whl (5.6 kB)
# ...
#   Using cached beautifulsoup4-4.6.3-py3-none-any.whl (90 kB)
# ...
